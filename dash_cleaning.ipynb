# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotnine import *

# %%
# Read data for each year

df23 = pd.read_csv('d23.csv')
df23.rename(columns={'PAGU DIPA AWAL KL': 'PAGU DIPA AWAL'}, inplace=True)
df23.rename(columns={'PAGU DIPA REVISI KL': 'PAGU DIPA REVISI'}, inplace=True)
df23.rename(columns={'PAGU HIMPUNAN KL': 'PAGU HIMPUNAN'}, inplace=True)
df23.rename(columns={'BLOKIR DIPA AWAL KL': 'BLOKIR DIPA AWAL'}, inplace=True)
df23.rename(columns={'BLOKIR DIPA REVISI KL': 'BLOKIR DIPA REVISI'}, inplace=True)
df23.rename(columns={'BLOKIR HIMPUNAN KL': 'BLOKIR HIMPUNAN'}, inplace=True)
df23['Tahun'] = '2023'

df24 = pd.read_csv('d24.csv')
df24.rename(columns={'PAGU DIPA AWAL KL': 'PAGU DIPA AWAL'}, inplace=True)
df24.rename(columns={'PAGU DIPA REVISI KL': 'PAGU DIPA REVISI'}, inplace=True)
df24.rename(columns={'PAGU KEPPRES': 'PAGU PERPRES'}, inplace=True)
df24.rename(columns={'BLOKIR DIPA AWAL KL': 'BLOKIR DIPA AWAL'}, inplace=True)
df24.rename(columns={'BLOKIR DIPA REVISI KL': 'BLOKIR DIPA REVISI'}, inplace=True)
df24.rename(columns={'BLOKIR KEPPRES': 'BLOKIR PERPRES'}, inplace=True)
df24['Tahun'] = '2024'

df25 = pd.read_csv('d25.csv')
df25.rename(columns={'PAGU PERPRES MP': 'PAGU PERPRES'}, inplace=True)
df25.rename(columns={'BLOKIR PERPRES MP': 'BLOKIR PERPRES'}, inplace=True)
df25['Tahun'] = '2025'

df26 = pd.read_csv('d26.csv')
df26['Tahun'] = '2026'

# %%
# Create a dictionary to hold column names for each dataframe
column_dict = {
    'df23': df23.columns,
    'df24': df24.columns,
    'df25': df25.columns,
    'df26': df26.columns
}

# Get a set of all unique column names across all dataframes
all_columns = set()
for cols in column_dict.values():
    all_columns.update(cols)

# Create a comparison dataframe
comparison_df = pd.DataFrame(index=sorted(list(all_columns)))

# Populate the comparison dataframe
for df_name, cols in column_dict.items():
    comparison_df[df_name] = comparison_df.index.isin(cols)

# Display the comparison table
print("Column presence in each DataFrame (True = exists, False = does not exist):")
print(comparison_df)
# Out:
# Column presence in each DataFrame (True = exists, False = does not exist):
#                                df23  df24  df25   df26
# AKUN 4 DIGIT                   True  True  True   True
# BLOKIR DIPA AWAL               True  True  True   True
# BLOKIR DIPA REVISI             True  True  True  False
# BLOKIR HIMPUNAN                True  True  True   True
# BLOKIR PERPRES                False  True  True   True
# FUNGSI                         True  True  True   True
# JENIS BELANJA                  True  True  True   True
# KEGIATAN                       True  True  True   True
# KEMENTERIAN/LEMBAGA            True  True  True   True
# KOMPONEN                       True  True  True   True
# OUTPUT (KRO)                   True  True  True   True
# PAGU DIPA AWAL                 True  True  True   True
# PAGU DIPA REVISI               True  True  True  False
# PAGU HIMPUNAN                  True  True  True   True
# PAGU PERPRES                  False  True  True   True
# PROGRAM                        True  True  True   True
# REALISASI BELANJA KL (SAKTI)   True  True  True  False
# SUB FUNGSI                     True  True  True   True
# SUB OUTPUT (RO)                True  True  True   True
# SUMBER DANA                    True  True  True   True
# Tahun                          True  True  True   True

# %%
df = pd.concat([df23, df24, df25, df26], ignore_index=True).reset_index(drop=True)
df['PAGU DIPA AWAL EFEKTIF'] = df['PAGU DIPA AWAL'] - df['BLOKIR DIPA AWAL']
df['PAGU DIPA REVISI EFEKTIF'] = df['PAGU DIPA REVISI'] - df['BLOKIR DIPA REVISI']
df['PAGU HIMPUNAN EFEKTIF'] = df['PAGU HIMPUNAN'] - df['BLOKIR HIMPUNAN']
df['PAGU PERPRES EFEKTIF'] = df['PAGU PERPRES'] - df['BLOKIR PERPRES']

# %%
# Ensure Tahun is string and trimmed (works whether it's numeric or string)
df['Tahun'] = df['Tahun'].astype(str).str.strip()

# Create a helper column with the leading token (the "digit" before the first space)
df['kl_digit'] = df['KEMENTERIAN/LEMBAGA'].astype(str).str.strip().str.split().str[0]

# Build mapping: digit -> full KEMENTERIAN/LEMBAGA from Tahun == 2025
# If multiple 2025 rows share the same digit we take the most common name (mode) or first one
mapping_series = (
    df[df['Tahun'] == '2025']
    .groupby('kl_digit')['KEMENTERIAN/LEMBAGA']
    .agg(lambda x: x.mode().iat[0] if not x.mode().empty else x.iloc[0])
)

mapping = mapping_series.to_dict()

if not mapping:
    st.warning("Tidak ada mapping dari Tahun 2025 ditemukan (kolom 'KEMENTERIAN/LEMBAGA' mungkin kosong).")
else:
    # Apply mapping to rows in 2023 and 2024 where kl_digit exists in mapping
    mask = df['Tahun'].isin(['2023', '2024']) & df['kl_digit'].isin(mapping.keys())
    # Map kl_digit -> full 2025 name
    df.loc[mask, 'KEMENTERIAN/LEMBAGA'] = df.loc[mask, 'kl_digit'].map(mapping)

# Clean up helper column
df = df.drop(columns=['kl_digit'])

df['PROGRAM'] = df['PROGRAM'].str[4:]

# Remove 4-digit prefix from KOMPONEN when the first 4 chars are digits

mask = df['KOMPONEN'].notna() & df['KOMPONEN'].str[:4].str.isdigit()
df.loc[mask, 'KOMPONEN'] = df.loc[mask, 'KOMPONEN'].str[4:].str.lstrip()

# Drop sentinel/placeholder K/L rows (case-insensitive, handles variants starting with '999')
df['KEMENTERIAN/LEMBAGA'] = df['KEMENTERIAN/LEMBAGA'].astype(str).str.strip()
drop_mask = df['KEMENTERIAN/LEMBAGA'].str.upper().str.contains(r'(^999\b)|BAGIAN ANGGARAN BENDAHARA UMUM NEGARA', na=False)
n_dropped = drop_mask.sum()
if n_dropped:
    print(f"Dropping {n_dropped} rows matching placeholder K/L")
df = df[~drop_mask].reset_index(drop=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3232\1649442922.py:37: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# Dropping 233 rows matching placeholder K/L

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660403 entries, 0 to 660402
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   KEMENTERIAN/LEMBAGA           660403 non-null  object
#  1   SUMBER DANA                   660403 non-null  object
#  2   FUNGSI                        660403 non-null  object
#  3   SUB FUNGSI                    660403 non-null  object
#  4   PROGRAM                       660403 non-null  object
#  5   KEGIATAN                      660403 non-null  object
#  6   OUTPUT (KRO)                  660403 non-null  object
#  7   SUB OUTPUT (RO)               660403 non-null  object
#  8   KOMPONEN                      660403 non-null  object
#  9   JENIS BELANJA                 660403 non-null  object
#  10  AKUN 4 DIGIT                  660403 non-null  object
#  11  REALISASI BELANJA KL (SAKTI)  323742 non-null  float64
#  12  PAGU DIPA REVISI              352858 non-null  float64
#  13  BLOKIR DIPA REVISI            352858 non-null  float64
#  14  PAGU DIPA AWAL                429926 non-null  float64
#  15  BLOKIR DIPA AWAL              429926 non-null  float64
#  16  PAGU HIMPUNAN                 357519 non-null  float64
#  17  BLOKIR HIMPUNAN               357519 non-null  float64
#  18  Tahun                         660403 non-null  object
#  19  PAGU PERPRES                  300023 non-null  float64
#  20  BLOKIR PERPRES                300023 non-null  float64
#  21  PAGU DIPA AWAL EFEKTIF        429926 non-null  float64
#  22  PAGU DIPA REVISI EFEKTIF      352858 non-null  float64
#  23  PAGU HIMPUNAN EFEKTIF         357519 non-null  float64
#  24  PAGU PERPRES EFEKTIF          300023 non-null  float64
# dtypes: float64(13), object(12)
# memory usage: 126.0+ MB

# %%
df.columns
# Out:
# Index(['KEMENTERIAN/LEMBAGA', 'SUMBER DANA', 'FUNGSI', 'SUB FUNGSI', 'PROGRAM',
#        'KEGIATAN', 'OUTPUT (KRO)', 'SUB OUTPUT (RO)', 'KOMPONEN',
#        'JENIS BELANJA', 'AKUN 4 DIGIT', 'REALISASI BELANJA KL (SAKTI)',
#        'PAGU DIPA REVISI', 'BLOKIR DIPA REVISI', 'PAGU DIPA AWAL',
#        'BLOKIR DIPA AWAL', 'PAGU HIMPUNAN', 'BLOKIR HIMPUNAN', 'Tahun',
#        'PAGU PERPRES', 'BLOKIR PERPRES', 'PAGU DIPA AWAL EFEKTIF',
#        'PAGU DIPA REVISI EFEKTIF', 'PAGU HIMPUNAN EFEKTIF',
#        'PAGU PERPRES EFEKTIF'],
#       dtype='object')

# %%
df.to_csv('df.csv')

# %% [markdown]
# ## Cleaning for Monitoring

# %%
df_04 = pd.read_csv('df_20251204.csv')
df_04['Tahun'] = '2026'
df_04['PAGU DIPA AWAL EFEKTIF'] = df_04['PAGU DIPA AWAL'] - df_04['BLOKIR DIPA AWAL']
df_04['PAGU HIMPUNAN EFEKTIF'] = df_04['PAGU HIMPUNAN'] - df_04['BLOKIR HIMPUNAN']
df_04['PAGU PERPRES EFEKTIF'] = df_04['PAGU PERPRES'] - df_04['BLOKIR PERPRES']
df_04.to_csv('df_20251204_cleaned.csv')

# %%
df_04
# Out:
#                              KEMENTERIAN/LEMBAGA  \
# 0       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)
# 1       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)
# 2       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)
# 3       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)
# 4       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)
# ...                                          ...
# 499995                     025 KEMENTERIAN AGAMA
# 499996                     025 KEMENTERIAN AGAMA
# 499997                     025 KEMENTERIAN AGAMA
# 499998                     025 KEMENTERIAN AGAMA
# 499999                     025 KEMENTERIAN AGAMA
#
#                             UNIT/ESELON I  \
# 0       001 01 Deputi Bidang Administrasi
# 1       001 01 Deputi Bidang Administrasi
# 2       001 01 Deputi Bidang Administrasi
# 3       001 01 Deputi Bidang Administrasi
# 4       001 01 Deputi Bidang Administrasi
# ...                                   ...
# 499995     025 04 Ditjen Pendidikan Islam
# 499996     025 04 Ditjen Pendidikan Islam
# 499997     025 04 Ditjen Pendidikan Islam
# 499998     025 04 Ditjen Pendidikan Islam
# 499999     025 04 Ditjen Pendidikan Islam
#
#                                                   SATKER      SUMBER DANA  \
# 0                            000017 SEKRETARIAT JENDERAL  01 RUPIAH MURNI
# 1                            000017 SEKRETARIAT JENDERAL  01 RUPIAH MURNI
# 2                            000017 SEKRETARIAT JENDERAL  01 RUPIAH MURNI
# 3                            000017 SEKRETARIAT JENDERAL  01 RUPIAH MURNI
# 4                            000017 SEKRETARIAT JENDERAL  01 RUPIAH MURNI
# ...                                                  ...              ...
# 499995  575422 MADRASAH ALIYAH NEGERI 5 GARUT KAB. GARUT  01 RUPIAH MURNI
# 499996  575422 MADRASAH ALIYAH NEGERI 5 GARUT KAB. GARUT  01 RUPIAH MURNI
# 499997  575422 MADRASAH ALIYAH NEGERI 5 GARUT KAB. GARUT  01 RUPIAH MURNI
# 499998  575422 MADRASAH ALIYAH NEGERI 5 GARUT KAB. GARUT  01 RUPIAH MURNI
# 499999  575422 MADRASAH ALIYAH NEGERI 5 GARUT KAB. GARUT  01 RUPIAH MURNI
#
#                    FUNGSI                                         SUB FUNGSI  \
# 0       01 PELAYANAN UMUM  01 01 LEMBAGA EKSEKUTIF DAN LEGISLATIF, MASALA...
# 1       01 PELAYANAN UMUM  01 01 LEMBAGA EKSEKUTIF DAN LEGISLATIF, MASALA...
# 2       01 PELAYANAN UMUM  01 01 LEMBAGA EKSEKUTIF DAN LEGISLATIF, MASALA...
# 3       01 PELAYANAN UMUM  01 01 LEMBAGA EKSEKUTIF DAN LEGISLATIF, MASALA...
# 4       01 PELAYANAN UMUM  01 01 LEMBAGA EKSEKUTIF DAN LEGISLATIF, MASALA...
# ...                   ...                                                ...
# 499995      10 PENDIDIKAN                10 02 PENDIDIKAN DASAR DAN MENENGAH
# 499996      10 PENDIDIKAN           10 90  PENDIDIKAN DAN KEBUDAYAAN LAINNYA
# 499997      10 PENDIDIKAN           10 90  PENDIDIKAN DAN KEBUDAYAAN LAINNYA
# 499998      10 PENDIDIKAN           10 90  PENDIDIKAN DAN KEBUDAYAAN LAINNYA
# 499999      10 PENDIDIKAN           10 90  PENDIDIKAN DAN KEBUDAYAAN LAINNYA
#
#                                          PROGRAM  \
# 0           001 01 WA Program Dukungan Manajemen
# 1           001 01 WA Program Dukungan Manajemen
# 2           001 01 WA Program Dukungan Manajemen
# 3           001 01 WA Program Dukungan Manajemen
# 4           001 01 WA Program Dukungan Manajemen
# ...                                          ...
# 499995  025 04 DF Program Wajib Belajar 13 Tahun
# 499996      025 04 WA Program Dukungan Manajemen
# 499997      025 04 WA Program Dukungan Manajemen
# 499998      025 04 WA Program Dukungan Manajemen
# 499999      025 04 WA Program Dukungan Manajemen
#
#                                                  KEGIATAN  \
# 0       1001 Pengelolaan Administrasi dan Fasilitasi R...
# 1       1001 Pengelolaan Administrasi dan Fasilitasi R...
# 2       1001 Pengelolaan Administrasi dan Fasilitasi R...
# 3       1001 Pengelolaan Administrasi dan Fasilitasi R...
# 4       1001 Pengelolaan Administrasi dan Fasilitasi R...
# ...                                                   ...
# 499995  2129 Pengelolaan dan Pembinaan Pendidikan Madr...
# 499996  2135 Dukungan Manajemen Pendidikan dan Pelayan...
# 499997  2135 Dukungan Manajemen Pendidikan dan Pelayan...
# 499998  2135 Dukungan Manajemen Pendidikan dan Pelayan...
# 499999  2135 Dukungan Manajemen Pendidikan dan Pelayan...
#
#                                         OUTPUT (KRO)  \
# 0       1001 EBA Layanan Dukungan Manajemen Internal
# 1       1001 EBA Layanan Dukungan Manajemen Internal
# 2       1001 EBA Layanan Dukungan Manajemen Internal
# 3       1001 EBA Layanan Dukungan Manajemen Internal
# 4       1001 EBA Layanan Dukungan Manajemen Internal
# ...                                              ...
# 499995          2129 QEN Tidak Terdapat di Referensi
# 499996  2135 EBA Layanan Dukungan Manajemen Internal
# 499997  2135 EBA Layanan Dukungan Manajemen Internal
# 499998  2135 EBA Layanan Dukungan Manajemen Internal
# 499999  2135 EBA Layanan Dukungan Manajemen Internal
#
#                             SUB OUTPUT (RO)  ... PAGU DIPA AWAL  \
# 0                1001 EBA 957 Layanan Hukum  ...            NaN
# 1                1001 EBA 957 Layanan Hukum  ...            NaN
# 2                1001 EBA 957 Layanan Hukum  ...            NaN
# 3                1001 EBA 957 Layanan Hukum  ...            NaN
# 4                1001 EBA 957 Layanan Hukum  ...            NaN
# ...                                     ...  ...            ...
# 499995  2129 QEN 007 Siswa MA  Penerima BOS  ...     85008000.0
# 499996     2135 EBA 994 Layanan Perkantoran  ...            NaN
# 499997     2135 EBA 994 Layanan Perkantoran  ...            NaN
# 499998     2135 EBA 994 Layanan Perkantoran  ...            NaN
# 499999     2135 EBA 994 Layanan Perkantoran  ...            NaN
#
#        BLOKIR DIPA AWAL PAGU PERPRES  BLOKIR PERPRES  PAGU HIMPUNAN  \
# 0                   NaN  143400000.0             0.0    145020000.0
# 1                   NaN   14400000.0             0.0     14400000.0
# 2                   NaN    8160000.0             0.0      8160000.0
# 3                   NaN   37152000.0             0.0     36180000.0
# 4                   NaN   10800000.0             0.0     10800000.0
# ...                 ...          ...             ...            ...
# 499995              0.0   85008000.0             0.0            NaN
# 499996              NaN   84039000.0             0.0     84039000.0
# 499997              NaN   12222000.0             0.0     12222000.0
# 499998              NaN    7500000.0             0.0      7500000.0
# 499999              NaN   19000000.0             0.0     19000000.0
#
#         BLOKIR HIMPUNAN  Tahun  PAGU DIPA AWAL EFEKTIF  PAGU HIMPUNAN EFEKTIF  \
# 0                   0.0   2026                     NaN            145020000.0
# 1                   0.0   2026                     NaN             14400000.0
# 2                   0.0   2026                     NaN              8160000.0
# 3                   0.0   2026                     NaN             36180000.0
# 4                   0.0   2026                     NaN             10800000.0
# ...                 ...    ...                     ...                    ...
# 499995              NaN   2026              85008000.0                    NaN
# 499996              0.0   2026                     NaN             84039000.0
# 499997              0.0   2026                     NaN             12222000.0
# 499998              0.0   2026                     NaN              7500000.0
# 499999              0.0   2026                     NaN             19000000.0
#
#        PAGU PERPRES EFEKTIF
# 0               143400000.0
# 1                14400000.0
# 2                 8160000.0
# 3                37152000.0
# 4                10800000.0
# ...                     ...
# 499995           85008000.0
# 499996           84039000.0
# 499997           12222000.0
# 499998            7500000.0
# 499999           19000000.0
#
# [500000 rows x 23 columns]

# %%
df_10 = pd.read_csv('df_20251210.csv')
df_10['Tahun'] = '2026'
df_10['PAGU DIPA AWAL EFEKTIF'] = df_10['PAGU DIPA AWAL'] - df_10['BLOKIR DIPA AWAL']
df_10['PAGU HIMPUNAN EFEKTIF'] = df_10['PAGU HIMPUNAN'] - df_10['BLOKIR HIMPUNAN']
df_10['PAGU PERPRES EFEKTIF'] = df_10['PAGU PERPRES'] - df_10['BLOKIR PERPRES']
df_10.to_csv('df_20251210_cleaned.csv')

# %%
df_18 = pd.read_csv('df_20251218.csv')
df_18['Tahun'] = '2026'
df_18['PAGU DIPA AWAL EFEKTIF'] = df_18['PAGU DIPA AWAL'] - df_18['BLOKIR DIPA AWAL']
df_18['PAGU HIMPUNAN EFEKTIF'] = df_18['PAGU HIMPUNAN'] - df_18['BLOKIR HIMPUNAN']
df_18['PAGU PERPRES EFEKTIF'] = df_18['PAGU PERPRES'] - df_18['BLOKIR PERPRES']
df_18.to_csv('df_20251218_cleaned.csv')

# %% [markdown]
# ## Data Prep for Klasifikasi Jenis Belanja

# %%
jb25 = pd.read_csv('jb25.csv')
jb25.rename(columns={'PAGU PERPRES MP': 'PAGU PERPRES'}, inplace=True)
jb25.rename(columns={'BLOKIR PERPRES MP': 'BLOKIR PERPRES'}, inplace=True)
jb25['Tahun'] = '2025'

jb26 = pd.read_csv('jb26.csv')
jb26['Tahun'] = '2026'

# %%
# Create a dictionary to hold column names for each dataframe
jb_dict = {
    'jb25': jb25.columns,
    'jb26': jb26.columns
}

# Get a set of all unique column names across all dataframes
jb_columns = set()
for cols in jb_dict.values():
    jb_columns.update(cols)

# Create a comparison dataframe
comparison_jb = pd.DataFrame(index=sorted(list(jb_columns)))

# Populate the comparison dataframe
for df_name, cols in jb_dict.items():
    comparison_jb[df_name] = comparison_jb.index.isin(cols)
# Display the comparison table
print("Column presence in each DataFrame (True = exists, False = does not exist):")
print(comparison_jb)
# Out:
# Column presence in each DataFrame (True = exists, False = does not exist):
#                               jb25   jb26
# AKUN 1 DIGIT                  True   True
# AKUN 2 DIGIT                  True   True
# AKUN 3 DIGIT                  True   True
# AKUN 4 DIGIT                  True   True
# AKUN 5 DIGIT                  True   True
# AKUN 6 DIGIT                  True   True
# BLOKIR DIPA AWAL              True   True
# BLOKIR DIPA REVISI            True   True
# BLOKIR HIMPUNAN               True   True
# BLOKIR PERPRES                True   True
# KEMENTERIAN/LEMBAGA           True   True
# PAGU DIPA AWAL                True   True
# PAGU DIPA REVISI              True   True
# PAGU HIMPUNAN                 True   True
# PAGU PERPRES                  True   True
# REALISASI BELANJA KL (SAKTI)  True  False
# Tahun                         True   True

# %%
jb = pd.concat([jb25, jb26], ignore_index=True).reset_index(drop=True)
jb['PAGU DIPA AWAL EFEKTIF'] = jb['PAGU DIPA AWAL'] - jb['BLOKIR DIPA AWAL']
jb['PAGU DIPA REVISI EFEKTIF'] = jb['PAGU DIPA REVISI'] - jb['BLOKIR DIPA REVISI']
jb['PAGU HIMPUNAN EFEKTIF'] = jb['PAGU HIMPUNAN'] - jb['BLOKIR HIMPUNAN']
jb['PAGU PERPRES EFEKTIF'] = jb['PAGU PERPRES'] - jb['BLOKIR PERPRES']

# %%
jb
# Out:
#                              KEMENTERIAN/LEMBAGA      AKUN 1 DIGIT  \
# 0       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 1       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 2       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 3       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 4       001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# ...                                          ...               ...
# 14962  999 BAGIAN ANGGARAN BENDAHARA UMUM NEGARA      7 PEMBIAYAAN
# 14963  999 BAGIAN ANGGARAN BENDAHARA UMUM NEGARA      7 PEMBIAYAAN
# 14964  999 BAGIAN ANGGARAN BENDAHARA UMUM NEGARA      7 PEMBIAYAAN
# 14965  999 BAGIAN ANGGARAN BENDAHARA UMUM NEGARA      7 PEMBIAYAAN
# 14966  999 BAGIAN ANGGARAN BENDAHARA UMUM NEGARA      7 PEMBIAYAAN
#
#                     AKUN 2 DIGIT                            AKUN 3 DIGIT  \
# 0             51 BELANJA PEGAWAI          511 BELANJA GAJI DAN TUNJANGAN
# 1             51 BELANJA PEGAWAI          511 BELANJA GAJI DAN TUNJANGAN
# 2             51 BELANJA PEGAWAI          511 BELANJA GAJI DAN TUNJANGAN
# 3             51 BELANJA PEGAWAI          511 BELANJA GAJI DAN TUNJANGAN
# 4             51 BELANJA PEGAWAI          511 BELANJA GAJI DAN TUNJANGAN
# ...                          ...                                     ...
# 14962  72 PENGELUARAN PEMBIAYAAN  722 PENGELUARAN PEMBIAYAAN LUAR NEGERI
# 14963  72 PENGELUARAN PEMBIAYAAN             724 PENYERTAAN MODAL NEGARA
# 14964  72 PENGELUARAN PEMBIAYAAN                             725 RDI/RPD
# 14965  72 PENGELUARAN PEMBIAYAAN                             725 RDI/RPD
# 14966  72 PENGELUARAN PEMBIAYAAN    727 PENGELUARAN INVESTASI PEMERINTAH
#
#                                             AKUN 4 DIGIT  \
# 0                    5111 Belanja Gaji dan Tunjangan PNS
# 1                    5111 Belanja Gaji dan Tunjangan PNS
# 2                    5111 Belanja Gaji dan Tunjangan PNS
# 3                    5111 Belanja Gaji dan Tunjangan PNS
# 4                    5111 Belanja Gaji dan Tunjangan PNS
# ...                                                  ...
# 14962  7222 Pembiayaan Cicilan Pokok Utang Luar Neger...
# 14963  7242 Penyertaan Modal Negara pada Badan Intern...
# 14964                7252 Penerusan Pinjaman Luar Negeri
# 14965                7252 Penerusan Pinjaman Luar Negeri
# 14966                          7271 Investasi Pemerintah
#
#                                             AKUN 5 DIGIT  \
# 0                                 51111 Belanja Gaji PNS
# 1                                 51111 Belanja Gaji PNS
# 2                51112 Belanja Tunjangan-tunjangan I PNS
# 3                51112 Belanja Tunjangan-tunjangan I PNS
# 4                51112 Belanja Tunjangan-tunjangan I PNS
# ...                                                  ...
# 14962  72221 Cicilan Pokok Utang Luar Negeri – Pinjam...
# 14963  72421 Penyertaan Modal Negara pada Badan Inter...
# 14964  72521 Penerusan Pinjaman Luar Negeri Tahun Ang...
# 14965  72521 Penerusan Pinjaman Luar Negeri Tahun Ang...
# 14966                         72711 Investasi pemerintah
#
#                                             AKUN 6 DIGIT  \
# 0                          511111 Belanja Gaji Pokok PNS
# 1                     511119 Belanja Pembulatan Gaji PNS
# 2                   511121 Belanja Tunj. Suami/Istri PNS
# 3                          511122 Belanja Tunj. Anak PNS
# 4                    511123 Belanja Tunj. Struktural PNS
# ...                                                  ...
# 14962  722213 Pengeluaran Pembiayaan Cicilan Pokok Ut...
# 14963  724211 Penyertaan Modal Negara pada Organisasi...
# 14964  725211 Penerusan Pinjaman Luar Negeri Kepada D...
# 14965  725213 Penerusan Pinjaman Luar Negeri Kepada B...
# 14966                        727111 Investasi Pemerintah
#
#        REALISASI BELANJA KL (SAKTI)  BLOKIR DIPA REVISI  PAGU DIPA REVISI  \
# 0                      1.733810e+10        0.000000e+00      1.826608e+10
# 1                      2.319830e+05        0.000000e+00      4.410000e+05
# 2                      1.219771e+09        0.000000e+00      1.334635e+09
# 3                      3.322734e+08        0.000000e+00      4.427910e+08
# 4                      1.345030e+09        0.000000e+00      1.536220e+09
# ...                             ...                 ...               ...
# 14962                           NaN        0.000000e+00      5.610467e+13
# 14963                           NaN        1.960281e+12      1.960281e+12
# 14964                           NaN        0.000000e+00      2.452572e+12
# 14965                           NaN        0.000000e+00      9.372567e+11
# 14966                           NaN        0.000000e+00      1.000000e+12
#
#        ...  PAGU DIPA AWAL  BLOKIR PERPRES  PAGU PERPRES  BLOKIR HIMPUNAN  \
# 0      ...    2.060156e+10             0.0  2.060156e+10              0.0
# 1      ...    5.020000e+05             0.0  5.020000e+05              0.0
# 2      ...    1.520140e+09             0.0  1.520140e+09              0.0
# 3      ...    5.150710e+08             0.0  5.150710e+08              0.0
# 4      ...    1.536220e+09             0.0  1.536220e+09              0.0
# ...    ...             ...             ...           ...              ...
# 14962  ...             NaN             NaN           NaN              NaN
# 14963  ...             NaN             NaN           NaN              NaN
# 14964  ...             NaN             NaN           NaN              NaN
# 14965  ...             NaN             NaN           NaN              NaN
# 14966  ...             NaN             NaN           NaN              NaN
#
#        PAGU HIMPUNAN  Tahun PAGU DIPA AWAL EFEKTIF  PAGU DIPA REVISI EFEKTIF  \
# 0       2.055550e+10   2025           2.060156e+10              1.826608e+10
# 1       6.780000e+05   2025           5.020000e+05              4.410000e+05
# 2       1.456855e+09   2025           1.520140e+09              1.334635e+09
# 3       4.886360e+08   2025           5.150710e+08              4.427910e+08
# 4       1.536220e+09   2025           1.536220e+09              1.536220e+09
# ...              ...    ...                    ...                       ...
# 14962            NaN   2026                    NaN              5.610467e+13
# 14963            NaN   2026                    NaN              0.000000e+00
# 14964            NaN   2026                    NaN              2.452572e+12
# 14965            NaN   2026                    NaN              9.372567e+11
# 14966            NaN   2026                    NaN              1.000000e+12
#
#        PAGU HIMPUNAN EFEKTIF  PAGU PERPRES EFEKTIF
# 0               2.055550e+10          2.060156e+10
# 1               6.780000e+05          5.020000e+05
# 2               1.456855e+09          1.520140e+09
# 3               4.886360e+08          5.150710e+08
# 4               1.536220e+09          1.536220e+09
# ...                      ...                   ...
# 14962                    NaN                   NaN
# 14963                    NaN                   NaN
# 14964                    NaN                   NaN
# 14965                    NaN                   NaN
# 14966                    NaN                   NaN
#
# [14967 rows x 21 columns]

# %%
# Ensure Tahun is string and trimmed (works whether it's numeric or string)
jb['Tahun'] = jb['Tahun'].astype(str).str.strip()

# Drop sentinel/placeholder K/L rows (case-insensitive, handles variants starting with '999')
jb['KEMENTERIAN/LEMBAGA'] = jb['KEMENTERIAN/LEMBAGA'].astype(str).str.strip()
drop_mask = jb['KEMENTERIAN/LEMBAGA'].str.upper().str.contains(r'(^999\b)|BAGIAN ANGGARAN BENDAHARA UMUM NEGARA', na=False)
n_dropped = drop_mask.sum()
if n_dropped:
    print(f"Dropping {n_dropped} rows matching placeholder K/L")
jb = jb[~drop_mask].reset_index(drop=True)
# Out:
# Dropping 250 rows matching placeholder K/L
# C:\Users\madeg\AppData\Local\Temp\ipykernel_26872\2037035257.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.

# %%
cat_cols = jb.select_dtypes(include=['object']).columns.tolist()
num_cols = jb.select_dtypes(include=['number']).columns.tolist()

print("String columns:", cat_cols)
print("Numeric columns:", num_cols)
# Out:
# String columns: ['KEMENTERIAN/LEMBAGA', 'AKUN 1 DIGIT', 'AKUN 2 DIGIT', 'AKUN 3 DIGIT', 'AKUN 4 DIGIT', 'AKUN 5 DIGIT', 'AKUN 6 DIGIT', 'Tahun']
# Numeric columns: ['REALISASI BELANJA KL (SAKTI)', 'BLOKIR DIPA REVISI', 'PAGU DIPA REVISI', 'BLOKIR DIPA AWAL', 'PAGU DIPA AWAL', 'BLOKIR PERPRES', 'PAGU PERPRES', 'BLOKIR HIMPUNAN', 'PAGU HIMPUNAN', 'PAGU DIPA AWAL EFEKTIF', 'PAGU DIPA REVISI EFEKTIF', 'PAGU HIMPUNAN EFEKTIF', 'PAGU PERPRES EFEKTIF']

# %%
jb
# Out:
#                                     KEMENTERIAN/LEMBAGA      AKUN 1 DIGIT  \
# 0              001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 1              001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 2              001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 3              001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# 4              001 MAJELIS PERMUSYAWARATAN RAKYAT (MPR)  5 BELANJA NEGARA
# ...                                                 ...               ...
# 14712     138 KEMENTERIAN PENDIDIKAN DASAR DAN MENENGAH  5 BELANJA NEGARA
# 14713                            027 KEMENTERIAN SOSIAL  5 BELANJA NEGARA
# 14714  103 BADAN NASIONAL PENANGGULANGAN BENCANA (BNPB)  5 BELANJA NEGARA
# 14715     138 KEMENTERIAN PENDIDIKAN DASAR DAN MENENGAH  5 BELANJA NEGARA
# 14716  103 BADAN NASIONAL PENANGGULANGAN BENCANA (BNPB)  5 BELANJA NEGARA
#
#                     AKUN 2 DIGIT  \
# 0             51 BELANJA PEGAWAI
# 1             51 BELANJA PEGAWAI
# 2             51 BELANJA PEGAWAI
# 3             51 BELANJA PEGAWAI
# 4             51 BELANJA PEGAWAI
# ...                          ...
# 14712  57 BELANJA BANTUAN SOSIAL
# 14713  57 BELANJA BANTUAN SOSIAL
# 14714  57 BELANJA BANTUAN SOSIAL
# 14715  57 BELANJA BANTUAN SOSIAL
# 14716  57 BELANJA BANTUAN SOSIAL
#
#                                             AKUN 3 DIGIT  \
# 0                         511 BELANJA GAJI DAN TUNJANGAN
# 1                         511 BELANJA GAJI DAN TUNJANGAN
# 2                         511 BELANJA GAJI DAN TUNJANGAN
# 3                         511 BELANJA GAJI DAN TUNJANGAN
# 4                         511 BELANJA GAJI DAN TUNJANGAN
# ...                                                  ...
# 14712  576 BELANJA BANTUAN SOSIAL UNTUK PENANGGULANGA...
# 14713  576 BELANJA BANTUAN SOSIAL UNTUK PENANGGULANGA...
# 14714  576 BELANJA BANTUAN SOSIAL UNTUK PENANGGULANGA...
# 14715  576 BELANJA BANTUAN SOSIAL UNTUK PENANGGULANGA...
# 14716  576 BELANJA BANTUAN SOSIAL UNTUK PENANGGULANGA...
#
#                                             AKUN 4 DIGIT  \
# 0                    5111 Belanja Gaji dan Tunjangan PNS
# 1                    5111 Belanja Gaji dan Tunjangan PNS
# 2                    5111 Belanja Gaji dan Tunjangan PNS
# 3                    5111 Belanja Gaji dan Tunjangan PNS
# 4                    5111 Belanja Gaji dan Tunjangan PNS
# ...                                                  ...
# 14712  5761 Belanja Bantuan Sosial Untuk Penanggulang...
# 14713  5761 Belanja Bantuan Sosial Untuk Penanggulang...
# 14714  5761 Belanja Bantuan Sosial Untuk Penanggulang...
# 14715  5761 Belanja Bantuan Sosial Untuk Penanggulang...
# 14716  5761 Belanja Bantuan Sosial Untuk Penanggulang...
#
#                                             AKUN 5 DIGIT  \
# 0                                 51111 Belanja Gaji PNS
# 1                                 51111 Belanja Gaji PNS
# 2                51112 Belanja Tunjangan-tunjangan I PNS
# 3                51112 Belanja Tunjangan-tunjangan I PNS
# 4                51112 Belanja Tunjangan-tunjangan I PNS
# ...                                                  ...
# 14712  57611 Belanja Bantuan Sosial Untuk Penanggulan...
# 14713  57611 Belanja Bantuan Sosial Untuk Penanggulan...
# 14714  57611 Belanja Bantuan Sosial Untuk Penanggulan...
# 14715  57611 Belanja Bantuan Sosial Untuk Penanggulan...
# 14716  57611 Belanja Bantuan Sosial Untuk Penanggulan...
#
#                                             AKUN 6 DIGIT  \
# 0                          511111 Belanja Gaji Pokok PNS
# 1                     511119 Belanja Pembulatan Gaji PNS
# 2                   511121 Belanja Tunj. Suami/Istri PNS
# 3                          511122 Belanja Tunj. Anak PNS
# 4                    511123 Belanja Tunj. Struktural PNS
# ...                                                  ...
# 14712  576111 Belanja Bantuan Sosial Untuk Penanggula...
# 14713  576112 Belanja Bantuan Sosial Untuk Penanggula...
# 14714  576112 Belanja Bantuan Sosial Untuk Penanggula...
# 14715  576112 Belanja Bantuan Sosial Untuk Penanggula...
# 14716  576113 Belanja Bantuan Sosial Untuk Penanggula...
#
#        REALISASI BELANJA KL (SAKTI)  BLOKIR DIPA REVISI  PAGU DIPA REVISI  \
# 0                      1.733810e+10                 0.0      1.826608e+10
# 1                      2.319830e+05                 0.0      4.410000e+05
# 2                      1.219771e+09                 0.0      1.334635e+09
# 3                      3.322734e+08                 0.0      4.427910e+08
# 4                      1.345030e+09                 0.0      1.536220e+09
# ...                             ...                 ...               ...
# 14712                           NaN                 0.0      1.400000e+10
# 14713                           NaN                 0.0      3.425202e+10
# 14714                           NaN                 0.0      1.573774e+11
# 14715                           NaN                 0.0      1.207200e+10
# 14716                           NaN                 0.0      4.529423e+10
#
#        ...  PAGU DIPA AWAL  BLOKIR PERPRES  PAGU PERPRES  BLOKIR HIMPUNAN  \
# 0      ...    2.060156e+10             0.0  2.060156e+10              0.0
# 1      ...    5.020000e+05             0.0  5.020000e+05              0.0
# 2      ...    1.520140e+09             0.0  1.520140e+09              0.0
# 3      ...    5.150710e+08             0.0  5.150710e+08              0.0
# 4      ...    1.536220e+09             0.0  1.536220e+09              0.0
# ...    ...             ...             ...           ...              ...
# 14712  ...    1.400000e+10             0.0  1.400000e+10              0.0
# 14713  ...    3.425202e+10             0.0  3.425202e+10              0.0
# 14714  ...    1.573774e+11             0.0  1.573774e+11              0.0
# 14715  ...    1.207200e+10             0.0  1.207200e+10              0.0
# 14716  ...    4.529423e+10             0.0  4.529423e+10              0.0
#
#        PAGU HIMPUNAN  Tahun PAGU DIPA AWAL EFEKTIF  PAGU DIPA REVISI EFEKTIF  \
# 0       2.055550e+10   2025           2.060156e+10              1.826608e+10
# 1       6.780000e+05   2025           5.020000e+05              4.410000e+05
# 2       1.456855e+09   2025           1.520140e+09              1.334635e+09
# 3       4.886360e+08   2025           5.150710e+08              4.427910e+08
# 4       1.536220e+09   2025           1.536220e+09              1.536220e+09
# ...              ...    ...                    ...                       ...
# 14712   1.100000e+10   2026           1.400000e+10              1.400000e+10
# 14713   3.756160e+10   2026           3.425202e+10              3.425202e+10
# 14714   1.573774e+11   2026           1.573774e+11              1.573774e+11
# 14715   1.450600e+10   2026           1.207200e+10              1.207200e+10
# 14716   4.529423e+10   2026           4.529423e+10              4.529423e+10
#
#        PAGU HIMPUNAN EFEKTIF  PAGU PERPRES EFEKTIF
# 0               2.055550e+10          2.060156e+10
# 1               6.780000e+05          5.020000e+05
# 2               1.456855e+09          1.520140e+09
# 3               4.886360e+08          5.150710e+08
# 4               1.536220e+09          1.536220e+09
# ...                      ...                   ...
# 14712           1.100000e+10          1.400000e+10
# 14713           3.756160e+10          3.425202e+10
# 14714           1.573774e+11          1.573774e+11
# 14715           1.450600e+10          1.207200e+10
# 14716           4.529423e+10          4.529423e+10
#
# [14717 rows x 21 columns]

# %%
jb.to_csv('jb.csv')
